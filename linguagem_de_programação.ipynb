# %% [markdown]
# <a href="https://colab.research.google.com/github/thiago-henrique-js/Ecotech/blob/main/linguagem_de_programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #u1_a1

# %%
print("hello world"
)
# Out:
# hello world

# %%
#criando variaveis

x = 10

nome = 'thiago'

nota = 8.75

fez_inscricao = True

# %%
#identificando as classes

print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
#criando uma caixa de texto

input('digite seu nome: ')
# Out:
# digite seu nome: thiago
# 'thiago'

# %%
#colocando as notas

nota_1 = int(input("digite a nota: "))
nota_2 = int(input("digite a nota: "))
nota_3 = int(input("digite a nota: "))
nota_4 = int(input("digite a nota: "))
# Out:
# digite a nota: 10
# digite a nota: 10
# digite a nota: 9
# digite a nota: 8

# %%
#calculo da media

media = (nota_1+nota_2+nota_3+nota_4)/4
print(media)
# Out:
# 9.25

# %%
#condicao

if media >= 6:
  situacao = 'aprovado'
else:
 situacao = 'reprovado'

# %%
#situacao

print(situacao)
# Out:
# aprovado
